# %%
# !pip install --upgrade tables
# !pip install eli5
# !pip install xgboost
# !pip install hyperopt

# %%
import pandas as pd
import numpy as np

import xgboost as xgb

from sklearn.metrics import mean_absolute_error as mae
from sklearn.model_selection import cross_val_score, KFold

from hyperopt import hp, fmin, tpe, STATUS_OK, STATUS_FAIL

import eli5
from eli5.sklearn import PermutationImportance

# %%
cd '/content/drive/My Drive/Colab Notebooks/Dataworshop_matrix/matrix_two/dw_matrix_car'
# Out:
# /content/drive/My Drive/Colab Notebooks/Dataworshop_matrix/matrix_two/dw_matrix_car

# %%
df = pd.read_hdf('data/car.h5')
df.shape
# Out:
# (106494, 155)

# %% [markdown]
# Feature Engineering:

# %%
SUFFIX_CAT = '__cat'

for feat in df.columns:
  if isinstance(df[feat][0], list): continue

  factorized_values = df[feat].factorize()[0]
  if SUFFIX_CAT in feat:
    df[feat] = factorized_values
  else:
    df[feat + SUFFIX_CAT] = factorized_values

# %%
df['param_rok-produkcji'] = df['param_rok-produkcji'].map(lambda x: -1 if str(x) == 'None' else int(x))
df['param_moc'] = df['param_moc'].map(lambda x: -1 if str(x) == 'None' else int(x.split(' ')[0]))
df['param_pojemność-skokowa'] = df['param_pojemność-skokowa'].map(lambda x: -1 if str(x) == 'None' else int(x.split('cm')[0].replace(' ','')))

# %%
feats = ['param_napęd__cat',
'param_rok-produkcji',
'param_stan__cat',
'param_skrzynia-biegów__cat',
'param_faktura-vat__cat',
'param_moc',
'param_marka-pojazdu__cat',
'feature_kamera-cofania__cat',
'param_typ__cat',
'param_pojemność-skokowa',
'seller_name__cat',
'feature_wspomaganie-kierownicy__cat',
'param_model-pojazdu__cat',
'param_wersja__cat',
'param_kod-silnika__cat',
'feature_system-start-stop__cat',
'feature_asystent-pasa-ruchu__cat',
'feature_czujniki-parkowania-przednie__cat',
'feature_łopatki-zmiany-biegów__cat',
'feature_regulowane-zawieszenie__cat']

# %%
def run_model(model, feats):
  X = df[feats].values
  y = df['price_value'].values

  scores = cross_val_score(model, X, y, cv=3, scoring='neg_mean_absolute_error')
  return  np.mean(scores), np.std(scores)

# %%
xgb_params = {
    'max_depth': 5,
    'n_estimators': 50,
    'learning_rate': 0.1,
    'seed': 0
}

run_model(xgb.XGBRegressor(**xgb_params), feats)
# Out:
# [19:21:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:21:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:21:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-9569.227198767323, 72.83561801421891)

# %% [markdown]
# Hyperopt:

# %%
# target function - defining function, black box:
def obj_func(params):
  print("Training with params: ")
  print(params)

  try:
    mean_mae, score_std = run_model(xgb.XGBRegressor(**xgb_params), feats)
    return {'loss': np.abs(mean_mae), 'status': STATUS_OK}
  except: 
    print('Error: ')
    return {'loss': np.abs(mean_mae), 'status': STATUS_FAIL}

# space - limits of searching for reasonable values, limiting the frames for the optimizer:
xgb_reg_params = {
    'learning_rate':    hp.choice('learning_rate',      np.arange(0.05, 0.31, 0.09)),    # (0.05, 0.31, 0.05)
    'max_depth':        hp.choice('max_depth',          np.arange(5, 8, 1, dtype=int)),  # (5,16,1, dtype=int)
    'subsample':        hp.quniform('subsample',        0.5, 1, 0.1),                    #  0.5, 1, 0.05
    'colsample_bytree': hp.quniform('colsample_bytree', 0.5, 1, 0.1),                    #  0.5, 1, 0.05
    'objective':        'reg:squarederror',                                              # del warnings reg:squarederror
    'n_estimators':     100,
    'seed':             0,  
}


# run - hyperot calculate:
best = fmin(obj_func, xgb_reg_params, algo=tpe.suggest, max_evals=25)   #function, space, algorytm, number of iteration

best
# Out:
# Training with params:
# {'colsample_bytree': 0.6000000000000001, 'learning_rate': 0.23000000000000004, 'max_depth': 5, 'n_estimators': 100, 'objective': 'reg:squarederror', 'seed': 0, 'subsample': 0.6000000000000001}
# [19:58:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Training with params:
# {'colsample_bytree': 0.6000000000000001, 'learning_rate': 0.14, 'max_depth': 7, 'n_estimators': 100, 'objective': 'reg:squarederror', 'seed': 0, 'subsample': 0.5}
# [19:59:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...
